# %% [markdown]
# # EDA To Prediction (DieTanic)

# %% [markdown]
# ## Contents of the Notebook:
#
# #### Part1: Exploratory Data Analysis(EDA):
# 1)Analysis of the features.
#
# 2)Finding any relations or trends considering multiple features.
# #### Part2: Feature Engineering and Data Cleaning:
# 1)Adding any few features.
#
# 2)Removing redundant features.
#
# 3)Converting features into suitable form for modeling.
# #### Part3: Predictive Modeling
# 1)Running Basic Algorithms.
#
# 2)Cross Validation.
#
# 3)Ensembling.
#
# 4)Important Features Extraction.

# %% [markdown]
# ## Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
sns.set(font_scale=2.5)
import missingno as msno
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4dd599fe4140> in <module>
#       5 plt.style.use('seaborn')
#       6 sns.set(font_scale=2.5)
# ----> 7 import missingno as msno
#       8 import warnings
#       9 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'missingno'

# %%
data=pd.read_csv('../input/train.csv')
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1c7ffe8b41f6> in <module>
# ----> 1 data=pd.read_csv('../input/train.csv')
#       2 df_train = pd.read_csv('../input/train.csv')
#       3 df_test = pd.read_csv('../input/test.csv')
#
# ~/GitHub/learning/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/GitHub/learning/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/GitHub/learning/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/GitHub/learning/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/GitHub/learning/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../input/train.csv' does not exist: b'../input/train.csv'

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
df_train.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a0875e781763> in <module>
# ----> 1 df_train.describe()
#
# NameError: name 'df_train' is not defined

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# *Null data check

# %%
for col in df_train.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:   Survived	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %%
for col in df_test.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 20.57%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.24%
# column:      Cabin	 Percent of NaN value: 78.23%
# column:   Embarked	 Percent of NaN value: 0.00%

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %%
data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The **Age, Cabin and Embarked** have null values. I will try to fix them.

# %% [markdown]
# ### How many Survived??

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# ## Sex--> Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# ## Pclass --> Ordinal Feature

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_dd90895e_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #ffff66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #cee666;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #f4fa66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #f6fa66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #ffff66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #ffff66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #60b066;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #dfef66;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow2_col2 {
#             background-color:  #90c866;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #008066;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #008066;
#         }    #T_dd90895e_b338_11e9_9037_359d21046fderow3_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_dd90895e_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dd90895e_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >80</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >136</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >216</td>
#     </tr>    <tr>
#         <th id="T_dd90895e_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >97</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >87</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >184</td>
#     </tr>    <tr>
#         <th id="T_dd90895e_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >372</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >119</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow2_col2" class="data row2 col2" >491</td>
#     </tr>    <tr>
#         <th id="T_dd90895e_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >All</th>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >549</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow3_col1" class="data row3 col1" >342</td>
#         <td id="T_dd90895e_b338_11e9_9037_359d21046fderow3_col2" class="data row3 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #ffff66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #ffff66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #f1f866;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col3 {
#             background-color:  #ffff66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #96cb66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #a3d166;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #f1f866;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col3 {
#             background-color:  #cfe766;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #a7d366;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #85c266;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col2 {
#             background-color:  #6eb666;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col3 {
#             background-color:  #85c266;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #cde666;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #f0f866;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col2 {
#             background-color:  #ffff66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col3 {
#             background-color:  #f7fb66;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #008066;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col1 {
#             background-color:  #008066;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col2 {
#             background-color:  #008066;
#         }    #T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_ddf7a3be_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >3</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >6</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >72</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >91</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >70</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >72</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >77</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >91</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col2" class="data row2 col2" >300</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >45</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col1" class="data row3 col1" >17</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col2" class="data row3 col2" >47</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_ddf7a3be_b338_11e9_9037_359d21046fdelevel1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col0" class="data row4 col0" >216</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col1" class="data row4 col1" >184</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col2" class="data row4 col2" >491</td>
#         <td id="T_ddf7a3be_b338_11e9_9037_359d21046fderow4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
              data=df_train, satureation=.5,
               size=9, aspect=1
              )

# %% [markdown]
# ## Age--> Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %% [markdown]
# 보시다시피, 생존자 중 나이가 어린 경우가 많음을 볼 수 있습니다.

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col3 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col4 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col5 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col6 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col7 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col8 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col9 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col10 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col11 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col12 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col13 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col14 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col15 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col16 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col3 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col4 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col5 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col6 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col7 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col8 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col9 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col10 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col11 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col12 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col13 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col14 {
#             background-color:  #ffff66;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col15 {
#             background-color:  #008066;
#         }    #T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_df9b8a3c_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_df9b8a3c_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col3" class="data row0 col3" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col4" class="data row0 col4" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col5" class="data row0 col5" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col6" class="data row0 col6" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col7" class="data row0 col7" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col8" class="data row0 col8" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col9" class="data row0 col9" >182</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col10" class="data row0 col10" >2</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col11" class="data row0 col11" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col12" class="data row0 col12" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col13" class="data row0 col13" >125</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col14" class="data row0 col14" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col15" class="data row0 col15" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_df9b8a3c_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >2</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col3" class="data row1 col3" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col4" class="data row1 col4" >6</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col5" class="data row1 col5" >1</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_col6" class="data row1 col6" >0</td>
#         <td id="T_df9b8a3c_b338_11e9_9037_359d21046fderow1_c

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# ## Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e0b403cc_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #fcfe66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #d2e866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #f2f866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow0_col3 {
#             background-color:  #d8ec66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow0_col4 {
#             background-color:  #e8f466;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #f9fc66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #fcfe66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow1_col3 {
#             background-color:  #fbfd66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow1_col4 {
#             background-color:  #fbfd66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #e6f266;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #f0f866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow2_col2 {
#             background-color:  #eef666;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow2_col3 {
#             background-color:  #e8f466;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow2_col4 {
#             background-color:  #edf666;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow3_col2 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow3_col3 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow3_col4 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow4_col1 {
#             background-color:  #fefe66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow4_col2 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow4_col3 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow4_col4 {
#             background-color:  #ffff66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow5_col0 {
#             background-color:  #e3f166;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow5_col1 {
#             background-color:  #e6f266;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow5_col2 {
#             background-color:  #ecf666;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow5_col3 {
#             background-color:  #f8fc66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow5_col4 {
#             background-color:  #ebf566;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow6_col0 {
#             background-color:  #f9fc66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow6_col1 {
#             background-color:  #cde666;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow6_col2 {
#             background-color:  #e4f266;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow6_col3 {
#             background-color:  #bede66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow6_col4 {
#             background-color:  #dbed66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow7_col0 {
#             background-color:  #edf666;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow7_col1 {
#             background-color:  #bdde66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow7_col2 {
#             background-color:  #d3e966;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow7_col3 {
#             background-color:  #dcee66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow7_col4 {
#             background-color:  #d1e866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow8_col0 {
#             background-color:  #52a866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow8_col1 {
#             background-color:  #dcee66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow8_col2 {
#             background-color:  #81c066;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow8_col3 {
#             background-color:  #b0d866;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow8_col4 {
#             background-color:  #9acc66;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow9_col0 {
#             background-color:  #008066;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow9_col1 {
#             background-color:  #008066;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow9_col2 {
#             background-color:  #008066;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow9_col3 {
#             background-color:  #008066;
#         }    #T_e0b403cc_b338_11e9_9037_359d21046fderow9_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_e0b403cc_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" colspan=2>female</th>
#         <th class="col_heading level0 col2" colspan=2>male</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0</th>
#         <th class="col_heading level1 col1" >1</th>
#         <th class="col_heading level1 col2" >0</th>
#         <th class="col_heading level1 col3" >1</th>
#         <th class="col_heading level1 col4" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Embarked</th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e0b403cc_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#         <th id="T_e0b403cc_b338_11e9_9037_359d21046fdelevel1_row0" class="row_heading level1 row0" >1</th>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >1</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >42</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >25</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow0_col3" class="data row0 col3" >17</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow0_col4" class="data row0 col4" >85</td>
#     </tr>    <tr>
#         <th id="T_e0b403cc_b338_11e9_9037_359d21046fdelevel1_row1" class="row_heading level1 row1" >2</th>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >0</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >7</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >8</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow1_col3" class="data row1 col3" >2</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow1_col4" class="data row1 col4" >17</td>
#     </tr>    <tr>
#         <th id="T_e0b403cc_b338_11e9_9037_359d21046fdelevel1_row2" class="row_heading level1 row2" >3</th>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >8</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >15</td>
#         <td id="T_e0b403cc_b338_11e9_9037_359d21046fderow2_col2" class=

# %% [markdown]
# ### Chances for Survival by Port Of Embarkation

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e210785e_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #008066;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #008066;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #c4e266;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #77bb66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #f9fc66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #f0f866;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #fbfd66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #fbfd66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #f9fc66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow4_col1 {
#             background-color:  #fcfe66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow5_col0 {
#             background-color:  #ffff66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow5_col1 {
#             background-color:  #ffff66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow6_col0 {
#             background-color:  #fefe66;
#         }    #T_e210785e_b338_11e9_9037_359d21046fderow6_col1 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_e210785e_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >398</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >210</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >97</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >112</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >15</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >13</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >12</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow3_col1" class="data row3 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow4_col0" class="data row4 col0" >15</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow4_col1" class="data row4 col1" >3</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow5_col0" class="data row5 col0" >5</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow5_col1" class="data row5 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_e210785e_b338_11e9_9037_359d21046fdelevel0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow6_col0" class="data row6 col0" >7</td>
#         <td id="T_e210785e_b338_11e9_9037_359d21046fderow6_col1" class="data row6 col1" >0</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e2853fae_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #008066;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #008066;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #008066;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #7bbd66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #8ac466;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #c6e266;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #f6fa66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #eef666;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow2_col2 {
#             background-color:  #f8fc66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #fafc66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #fdfe66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow3_col2 {
#             background-color:  #fafc66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow4_col1 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow4_col2 {
#             background-color:  #f6fa66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow5_col0 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow5_col1 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow5_col2 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow6_col0 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow6_col1 {
#             background-color:  #ffff66;
#         }    #T_e2853fae_b338_11e9_9037_359d21046fderow6_col2 {
#             background-color:  #fefe66;
#         }</style>
# <table id="T_e2853fae_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SibSp</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >137</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >120</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >351</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >71</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >55</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >83</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >5</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >8</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow2_col2" class="data row2 col2" >15</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >3</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow3_col1" class="data row3 col1" >1</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow3_col2" class="data row3 col2" >12</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow4_col0" class="data row4 col0" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow4_col1" class="data row4 col1" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow4_col2" class="data row4 col2" >18</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow5_col0" class="data row5 col0" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow5_col1" class="data row5 col1" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_e2853fae_b338_11e9_9037_359d21046fdelevel0_row6" class="row_heading level0 row6" >8</th>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow6_col0" class="data row6 col0" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow6_col1" class="data row6 col1" >0</td>
#         <td id="T_e2853fae_b338_11e9_9037_359d21046fderow6_col2" class="data row6 col2" >7</td>
#     </tr></tbody>
# </table>

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다

# %%
print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
f,ax=plt.subplots(1, 3, figsize=(40,10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize',  y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize',  y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# ## Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e30f4564_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #008066;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow0_col1 {
#             background-color:  #008066;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow0_col2 {
#             background-color:  #008066;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #cfe766;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow1_col1 {
#             background-color:  #c2e066;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow1_col2 {
#             background-color:  #dbed66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #dfef66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow2_col1 {
#             background-color:  #e1f066;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow2_col2 {
#             background-color:  #e3f166;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow3_col1 {
#             background-color:  #fcfe66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow3_col2 {
#             background-color:  #fefe66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #fefe66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow4_col1 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow4_col2 {
#             background-color:  #fefe66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow5_col0 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow5_col1 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow5_col2 {
#             background-color:  #fdfe66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow6_col0 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow6_col1 {
#             background-color:  #ffff66;
#         }    #T_e30f4564_b338_11e9_9037_359d21046fderow6_col2 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_e30f4564_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Parch</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >163</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow0_col1" class="data row0 col1" >134</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow0_col2" class="data row0 col2" >381</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >31</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow1_col1" class="data row1 col1" >32</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow1_col2" class="data row1 col2" >55</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >21</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow2_col1" class="data row2 col1" >16</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow2_col2" class="data row2 col2" >43</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow3_col1" class="data row3 col1" >2</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow3_col2" class="data row3 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow4_col0" class="data row4 col0" >1</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow4_col1" class="data row4 col1" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow4_col2" class="data row4 col2" >3</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow5_col0" class="data row5 col0" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow5_col1" class="data row5 col1" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow5_col2" class="data row5 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_e30f4564_b338_11e9_9037_359d21046fdelevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow6_col0" class="data row6 col0" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow6_col1" class="data row6 col1" >0</td>
#         <td id="T_e30f4564_b338_11e9_9037_359d21046fderow6_col2" class="data row6 col2" >1</td>
#     </tr></tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()

# %% [markdown]
# ## Fare--> Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3      0            113803  53.1000  C123        S           2
# 4      0            373450   8.0500   NaN        S           1

# %%
df_train['Ticket'].value_counts()
# Out:
# 347082           7
# 1601             7
# CA. 2343         7
# CA 2144          6
# 347088           6
# 3101295          6
# S.O.C. 14879     5
# 382652           5
# 19950            4
# 4133             4
# PC 17757         4
# 113781           4
# W./C. 6608       4
# LINE             4
# 349909           4
# 17421            4
# 2666             4
# 113760           4
# 347077           4
# PC 17760         3
# PC 17755         3
# C.A. 34651       3
# 35273            3
# SC/Paris 2123    3
# 345773           3
# PC 17572         3
# 230080           3
# 347742           3
# 239853           3
# 24160            3
#                 ..
# 350042           1
# A/5 2466         1
# PC 17603         1
# 19952            1
# 2667             1
# PC 17600         1
# 392091           1
# 239854           1
# 234604           1
# 364498           1
# 248747           1
# C.A. 24580       1
# 3101265          1
# 349244           1
# 364850           1
# 364506           1
# A.5. 18509       1
# 367228           1
# 219533           1
# 7553             1
# 113028           1
# 8475             1
# 111320           1
# 111428           1
# 347064           1
# 250651           1
# 236853           1
# 345763           1
# 350036           1
# SC/PARIS 2149    1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')#checking the number of passenegers in each band
# Out:
# <style  type="text/css" >
#     #T_e4464aea_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #ffff66;
#         }    #T_e4464aea_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #d8ec66;
#         }    #T_e4464aea_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #40a066;
#         }    #T_e4464aea_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #289366;
#         }    #T_e4464aea_b338_11e9_9037_359d21046fderow4_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_e4464aea_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Age_band</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e4464aea_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_e4464aea_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >382</td>
#     </tr>    <tr>
#         <th id="T_e4464aea_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_e4464aea_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >325</td>
#     </tr>    <tr>
#         <th id="T_e4464aea_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >0</th>
#         <td id="T_e4464aea_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >104</td>
#     </tr>    <tr>
#         <th id="T_e4464aea_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_e4464aea_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >69</td>
#     </tr>    <tr>
#         <th id="T_e4464aea_b338_11e9_9037_359d21046fdelevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_e4464aea_b338_11e9_9037_359d21046fderow4_col0" class="data row4 col0" >11</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Age_band','Survived',data=data,col='Pclass')
plt.show()

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp']#family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1#Alone

f,ax=plt.subplots(1,2,figsize=(18,6))
sns.factorplot('Family_Size','Survived',data=data,ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone','Survived',data=data,ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.close(2)
plt.close(3)
plt.show()

# %%
sns.factorplot('Alone','Survived',data=data,hue='Sex',col='Pclass')
plt.show()

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e58c2884_b338_11e9_9037_359d21046fderow0_col0 {
#             background-color:  #ffff66;
#         }    #T_e58c2884_b338_11e9_9037_359d21046fderow1_col0 {
#             background-color:  #b9dc66;
#         }    #T_e58c2884_b338_11e9_9037_359d21046fderow2_col0 {
#             background-color:  #54aa66;
#         }    #T_e58c2884_b338_11e9_9037_359d21046fderow3_col0 {
#             background-color:  #008066;
#         }</style>
# <table id="T_e58c2884_b338_11e9_9037_359d21046fde" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Survived</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Fare_Range</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e58c2884_b338_11e9_9037_359d21046fdelevel0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#         <td id="T_e58c2884_b338_11e9_9037_359d21046fderow0_col0" class="data row0 col0" >0.197309</td>
#     </tr>    <tr>
#         <th id="T_e58c2884_b338_11e9_9037_359d21046fdelevel0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#         <td id="T_e58c2884_b338_11e9_9037_359d21046fderow1_col0" class="data row1 col0" >0.303571</td>
#     </tr>    <tr>
#         <th id="T_e58c2884_b338_11e9_9037_359d21046fdelevel0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#         <td id="T_e58c2884_b338_11e9_9037_359d21046fderow2_col0" class="data row2 col0" >0.454955</td>
#     </tr>    <tr>
#         <th id="T_e58c2884_b338_11e9_9037_359d21046fdelevel0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#         <td id="T_e58c2884_b338_11e9_9037_359d21046fderow3_col0" class="data row3 col0" >0.581081</td>
#     </tr></tbody>
# </table>

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.factorplot('Fare_cat','Survived',data=data,hue='Sex')
plt.show()

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
